# %%
conda install -c conda-forge gensim

# %%
from gensim.models import word2vec

# %%
import logging
import pandas as pd

# %%
import json
import os

# %%
training_text = ' '

# %%
path ='/Users/macbookpro/Desktop/Stats for Finance Assignement/666_20170904105517/666_webhose-2015-07_20170904105917'
# Out:
# /Users/macbookpro/Desktop/Stats for Finance Assignement/666_20170904105517/666_webhose-2015-07_20170904105917

# %%
def createtextfromjson(path,text):
    for filename in os.listdir(path):
        with open(path+'/'+filename) as read_it:
            documenttext=json.load(read_it)
        text = text + ' ' + documenttext['text']
        #print(filename)
    return training_text
        #print(documenttext['text'])

# %%
training = createtextfromjson(path,training_text)
# Out:
# news_0014010.json
# news_0008033.json
# news_0000403.json
# news_0004913.json
# news_0005601.json
# news_0011212.json
# news_0008463.json
# news_0014440.json
# news_0013385.json
# news_0006884.json
# news_0007796.json
# news_0000053.json
# news_0002594.json
# news_0005251.json
# news_0011642.json
# news_0008199.json
# news_0010950.json
# news_0008930.json
# news_0009622.json
# news_0001212.json
# news_0004010.json
# news_0010403.json
# news_0009272.json
# news_0012594.json
# news_0000950.json
# news_0001642.json
# news_0006187.json
# news_0004440.json
# news_0003385.json
# news_0010053.json
# news_0009788.json
# news_0002982.json
# news_0006168.json
# news_0003690.json
# news_0004155.json
# news_0010546.json
# news_0008875.json
# news_0012081.json
# news_0009767.json
# news_0006492.json
# news_0001357.json
# news_0006538.json
# news_0004505.json
# news_0010116.json
# news_0009337.json
# news_0000815.json
# news_0002828.json
# news_0001707.json
# news_0004856.json
# news_0005744.json
# ...

# %%
training
# Out:
# ' '
